# %%
# Import the genai module from Google's generative AI library
# This module helps us interact with Google's AI modelsfrom google import genai
from google import genai

# userdata is used to securely store and access secret keys like API keys
from google.colab import userdata

# Get the API key stored in Colab with the name "Text-gene"
# This keeps your API key hidden and secure
API_KEY = userdata.get("Text-gene")

# Create a client object using the API key
client = genai.Client(api_key=API_KEY)

# Send a request to the AI model to generate content
# - model: specifies which AI model to use
# - contents: the question or prompt we want the AI to answer
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="How does AI work?"
)
print(response.text)
# Out:
# At its simplest level, Artificial Intelligence (AI) is the ability of a computer program to perform tasks that usually require human intelligence, such as recognizing patterns, making decisions, or translating languages.
#
# Unlike traditional software, which follows a rigid list of "if-then" instructions written by a human, AI "learns" from data. Here is a breakdown of how that process works:
#
# ---
#
# ### 1. The Foundation: Data (The "Fuel")
# AI needs information to learn. This data can be text, images, sensor readings, or numbers.
# *   **Example:** To teach an AI to recognize a cat, you feed it thousands of photos labeled "cat" and thousands labeled "not a cat."
#
# ### 2. The Engine: Machine Learning (ML)
# ...
